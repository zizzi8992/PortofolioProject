# %% [markdown]
# **FINAL CAPSTONE PROJECT**
#
# In this project, we will visualize stock prices using Seaborn and Matplotlib. The 4 stocks that will be visualized are JP Morgan Chase (JP), Procter and Gamble (P&G) (PG), Apple (AAPL) and United Airlines (UAL). Using the “stock_daily_prices.csv” and “stocks_daily_returns.csv” included in the attachment, write Python scripts to perform the following tasks:
#
# *Import both data using Pandas.
#
# *Using Matplotlib, plot a lineplot showing all daily prices of 4 stocks in one figure.
#
# *Using Matplotlib, plot the daily prices of the 4 stocks in several subplots.
#
# *Using Matplotlib, visualize the 4 plots in subplots next to each other (all figures in one row).
#
# *Using Matplotlib, visualize a scatterplot between Apple's daily returns and JP Morgan's daily returns.
#
# *Using Seaborn, visualize a scatterplot between Apple's daily returns and JP Morgan's daily returns.
#
# *Assume that you decide to be bullish on AAPL and you allocate 70% of your assets in it. You also decide to divide your remaining assets equally among other stocks (JPM, PG, and UAL).
#
# *Using Matplotlib, plot a piechart showing these allocations. Use the ‘explode’ attribute to increase separation between AAPL and the rest of the portfolio.
#
# *Using Matplotlib, plot histograms for United Airlines and P&G returns using 40 bins in red. Show the average and Standard deviation for both stocks above the image.
#
# *Using Seaborn, a heatmap plot showing the correlation between daily stock returns.
#
# *Create a 3D plot showing all daily returns from JPM, AAPL, and UAL [need to figure out how to do this personally].

# %%
#IMPORT PD, NUMPY, SEABORN DAN MATPOTLIB
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import data daily prices
daily_prices_df = pd.read_csv('E:\_Portofolio\PortofolioProject\StockVisualization\stocks_daily_prices.csv')
daily_prices_df.head()
daily_prices_df.tail()
# Out:
#            Date        AAPL         JPM          PG        UAL
# 3637  6/13/2022  131.880005  115.989998  138.149994  37.020000
# 3638  6/14/2022  132.759995  114.059998  133.839996  36.990002
# 3639  6/15/2022  135.429993  115.410004  132.509995  37.889999
# 3640  6/16/2022  130.059998  113.430000  133.320007  34.779999
# 3641  6/17/2022  131.559998  113.029999  132.360001  36.279999

# %%
#plot multiple line plot 4 shares in one figure
daily_prices_df.plot(x = 'Date', y = ['AAPL', 'JPM', 'PG', 'UAL'], linewidth = 3, figsize = (14,6));
plt.ylabel('Price [$]')
plt.title('Daily Prices')
plt.legend(loc = 'upper left')
plt.grid()

# %%
#plot daily_prices_df prices in subplots
daily_prices_df.plot(x = 'Date', y = ['AAPL', 'JPM', 'PG', 'UAL'], linewidth = 3, figsize = (14,6), subplots = True);

# %%
#plot all subplots in one line using matplotlib
plt.figure(figsize = (20,4))

plt.subplot(1, 4, 1)
plt.plot(daily_prices_df['AAPL'], 'r--')
plt.grid()

plt.subplot(1, 4, 2)
plt.plot(daily_prices_df['JPM'], 'b.')
plt.grid()

plt.subplot(1, 4, 3)
plt.plot(daily_prices_df['PG'], 'g.')
plt.grid()

plt.subplot(1, 4, 4)
plt.plot(daily_prices_df['UAL'], 'y--')
plt.grid()

# %%
#EDA daily return
daily_returns_df = pd.read_csv('E:\_Portofolio\PortofolioProject\StockVisualization\stocks_daily_returns.csv')
daily_returns_df.head()
# Out:
#        Date      AAPL       JPM        PG        UAL
# 0  1/2/2008  0.000000  0.000000  0.000000   0.000000
# 1  1/3/2008  0.046203 -0.687708  0.000000  -0.750233
# 2  1/4/2008 -7.633517 -2.268378 -0.401072   4.409454
# 3  1/7/2008 -1.338518  1.001718  0.652615  -5.870973
# 4  1/8/2008 -3.597157 -3.967066  0.262103 -16.415356

# %%
daily_returns_df.tail()
# Out:
#            Date      AAPL       JPM        PG        UAL
# 3637  6/13/2022 -3.828484 -2.977838 -2.677001 -10.058308
# 3638  6/14/2022  0.667265 -1.663937 -3.119796  -0.081034
# 3639  6/15/2022  2.011147  1.183593 -0.993725   2.433084
# 3640  6/16/2022 -3.965145 -1.715625  0.611284  -8.207972
# 3641  6/17/2022  1.153314 -0.352642 -0.720077   4.312824

# %%
#scatterplot AAPL vs JPM (pt)
daily_returns_df.plot.scatter('AAPL', 'JPM', grid = True, figsize = (12, 6), color = 'hotpink', alpha = 0.5)
plt.show()

# %%
#scatterplot AAPL vs JPM (sns)
plt.figure(figsize = (12,6))
plt.grid()
sns.scatterplot(x = 'AAPL', y = 'JPM', data = daily_returns_df, alpha = 0.5)
plt.show()

# %%
#bullish 70% AAPL
# %matplotlib inline
stocks_df = pd.DataFrame(data = { 'allocation %' : [70, 10, 10, 10]}, index = ['AAPL', 'JPM', 'PG', 'UAL'])
stocks_df
# Out:
#       allocation %
# AAPL            70
# JPM             10
# PG              10
# UAL             10

# %%
#plot piechart using matpotlib
from seaborn._core.properties import Color

stocks_df.plot.pie( y = 'allocation %', figsize = (6,6), explode = [0.1, 0, 0, 0])
plt.title("STOCKS PORTOFOLIO PIE CHART")
plt.show()

# %%
#plot histogram UAL vs PG using matpotlib
muUAL = round(daily_returns_df['UAL'].mean(), 2)
muPG = round(daily_returns_df['PG'].mean(), 2)
sigmaUAL = round(daily_returns_df['UAL'].std(), 2)
sigmaPG = round(daily_returns_df['PG'].std(), 2)
num_bins = 40
plt.figure(figsize = (20,15))
daily_returns_df[['UAL', 'PG']].plot.hist(bins = num_bins, color = ['r', 'b'], alpha = 0.5)
plt.grid()
plt.ylabel('Probability')
plt.title('Histogram: muUAL =' + str(muUAL) + ' dan sigmaUAL =' + str(sigmaUAL) + ' & Histogram: muPG =' + str(muPG) + ' dan sigmaPG =' + str(sigmaPG));
plt.show()

# %%
#plot heatmap yang menunjukkan korelasi antara return harian saham using seaborn
plt.figure(figsize = (20, 10))
sns.heatmap(daily_returns_df.corr(), annot = True)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_11960\4255766675.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(daily_returns_df.corr(), annot = True)

# %%
#plot 3D
from mpl_toolkits.mplot3d import Axes3D
sns.set_style("whitegrid", {'axes.grid' : False})

fig = plt.figure(figsize=(15,15))

ax = fig.add_subplot(111, projection = '3d')

x = daily_returns_df['JPM'].tolist() #dibuat jadi list (array) datanya
y = daily_returns_df['AAPL'].tolist()
z = daily_returns_df['UAL'].tolist()


ax.scatter(x, y, z, c = 'r', marker='o', s = 10) # c=color, tanda/marker = o, s=besar bulatannya(marker float)
ax.set_xlabel('JPM')
ax.set_ylabel('AAPL')
ax.set_zlabel('UAL')

plt.show()

# %% [markdown]
# # FINISH
